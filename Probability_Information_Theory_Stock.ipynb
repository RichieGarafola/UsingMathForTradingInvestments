# %% [markdown]
# # Probability & Information Theory

# %% [markdown]
# http://egrcc.github.io/docs/dl/deeplearningbook-prob.pdf

# %%
import numpy as np
import scipy.stats as st
from math import factorial

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore") 

# yfinance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
symbol = 'AMD'


# Read data 
dataset = yf.download(symbol)

# View Columns
dataset.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Open      High       Low     Close  Adj Close  Volume
# Date
# 1980-03-17   0.0  3.302083  3.125000  3.145833   3.145833  219600
# 1980-03-18   0.0  3.125000  2.937500  3.031250   3.031250  727200
# 1980-03-19   0.0  3.083333  3.020833  3.041667   3.041667  295200
# 1980-03-20   0.0  3.062500  3.010417  3.010417   3.010417  159600
# 1980-03-21   0.0  3.020833  2.906250  2.916667   2.916667  130800

# %%
dataset['Returns'] = dataset['Adj Close'].pct_change()

# %%
dataset['Returns'] = dataset['Adj Close'].dropna()

# %%
Returns = np.array(dataset['Returns'])
Open = np.array(dataset['Open'])
Close = np.array(dataset['Adj Close'])
High = np.array(dataset['High'])
Low = np.array(dataset['Low'])

# %% [markdown]
# # 52 Cards in a Set

# %% [markdown]
# #### There are 13 cards of each suit, consisting of 1 Ace, 3 face cards, and 9 number cards. There are 4 Aces, 12 face cards, and 36 number cards in a 52 card deck. The number of spades, hearts, diamonds, and clubs is same in every pack of 52 cards.

# %%
# Number of cards
cards = 52 
# Outcomes (Number of Aces)
aces = 4
# Divide possible outcomes by the Number of Cards 
ace_probability = aces / cards
# Print probability rounded to two decimal places
ace_probability_percent = ace_probability * 100
print(str(round(ace_probability_percent, 0)) + '%')
# Out:
# 8.0%

# %% [markdown]
# ## Apply Stock data to probability

# %%
import collections

print([item for item, count in collections.Counter(Close).items() if count > 1])
# Out:
# [3.1458330154418945, 3.03125, 3.0416669845581055, 3.0104169845581055, 2.9166669845581055, 2.6666669845581055, 2.6041669845581055, 2.375, 2.5416669845581055, 2.7395830154418945, 2.625, 2.6354169845581055, 2.5625, 2.6145830154418945, 2.78125, 2.7083330154418945, 2.7291669845581055, 2.4583330154418945, 2.6875, 2.7708330154418945, 2.75, 3.0833330154418945, 3.1666669845581055, 3.1041669845581055, 3.0208330154418945, 3.0729169845581055, 3.0, 2.96875, 3.09375, 3.0625, 2.9375, 3.4583330154418945, 3.4375, 3.5, 3.6145830154418945, 3.7291669845581055, 3.7083330154418945, 3.6458330154418945, 3.5729169845581055, 3.5625, 3.5833330154418945, 3.5208330154418945, 4.3125, 4.2395830154418945, 4.2708330154418945, 4.4166669845581055, 4.3541669845581055, 4.3333330154418945, 4.1041669845581055, 4.1666669845581055, 4.5625, 4.5208330154418945, 4.4791669845581055, 4.375, 4.4375, 4.5, 4.3958330154418945, 5.25, 5.1145830154418945, 4.8333330154418945, 5.1770830154418945, 5.0416669845581055, 5.375, 5.4375, 5.1666669845581055, 5.2916669845581055, 5.2708330154418945, 5.1875, 5.1041669845581055, 4.9166669845581055, 5.0, 4.7916669845581055, 5.1458330154418945, 5.3541669845581055, 5.5208330154418945, 7.0, 6.9375, 6.6875, 6.25, 5.8333330154418945, 4.9583330154418945, 5.6875, 5.75, 5.875, 5.3125, 4.9375, 4.5416669845581055, 4.6666669845581055, 4.5833330154418945, 4.625, 4.6875, 4.7291669845581055, 4.8125, 4.6041669845581055, 4.0833330154418945, 4.1458330154418945, 4.125, 3.9375, 3.4791669845581055, 4.0, 4.0416669845581055, 4.2916669845581055, 3.9166669845581055, 3.8125, 3.7708330154418945, 3.875, 3.8958330154418945, 3.7916669845581055, 3.8541669845581055, 3.75, 3.6666669845581055, 3.9583330154418945, 3.8333330154418945, 4.2291669845581055, 4.1875, 4.4583330154418945, 4.25, 4.0625, 4.6458330154418945, 4.875, 4.75, 4.0208330154418945, 3.5416669845581055, 3.6875, 3.6041669845581055, 3.625, 3.4166669845581055, 3.3333330154418945, 3.2708330154418945, 3.25, 3.375, 3.2291669845581055, 3.2083330154418945, 3.2916669845581055, 3.1875, 2.9583330154418945, 2.9791669845581055, 2.8958330154418945, 2.8333330154418945, 2.5, 2.5833330154418945, 2.875, 3.125, 2.8541669845581055, 2.8125, 4.2083330154418945, 5.0625, 4.8958330154418945, 5.125, 5.625, 5.7916669845581055, 6.125, 5.9375, 6.0, 6.78125, 6.875, 6.5625, 6.625, 6.0625, 6.15625, 5.8125, 6.1875, 5.96875, 6.3125, 6.21875, 6.5, 6.75, 6.375, 7.25, 8.0, 8.34375, 8.90625, 8.6875, 8.875, 8.5625, 7.96875, 8.53125, 8.78125, 9.0, 8.75, 9.5, 9.21875, 8.4375, 9.34375, 9.0625, 8.9375, 9.4375, 9.6875, 9.3125, 9.125, 8.65625, 8.71875, 8.40625, 8.28125, 8.15625, 8.375, 8.8125, 8.96875, 8.5, 7.875, 7.9375, 9.40625, 9.25, 9.09375, 9.625, 9.46875, 9.375, 9.84375, 10.46875, 10.96875, 11.46875, 11.3125, 11.4375, 11.28125, 11.53125, 11.1875, 11.75, 11.96875, 13.09375, 12.5, 12.125, 12.625, 13.40625, 13.625, 13.1875, 13.0625, 12.65625, 13.65625, 13.46875, 13.5, 14.65625, 15.8125, 16.0625, 16.125, 15.25, 15.90625, 15.875, 15.4375, 14.75, 14.4375, 14.03125, 14.71875, 15.75, 16.28125, 16.5625, 14.84375, 14.875, 15.0, 14.5, 14.1875, 14.0, 13.375, 14.28125, 13.53125, 13.3125, 13.6875, 12.96875, 13.75, 14.625, 15.375, 15.3125, 16.0, 16.4375, 15.1875, 14.6875, 14.375, 15.0625, 15.5625, 16.3125, 16.8125, 15.625, 15.5, 14.8125, 15.125, 13.8125, 16.375, 16.75, 17.0625, 16.5, 16.6875, 17.6875, 17.0, 16.875, 17.1875, 16.625, 16.1875, 15.9375, 17.5625, 17.75, 18.0, 18.375, 17.9375, 17.8125, 17.875, 18.125, 17.625, 17.3125, 14.5625, 14.25, 13.875, 13.0, 13.9375, 14.125, 13.5625, 14.9375, 14.0625, 14.3125, 17.125, 17.375, 13.125, 12.8125, 13.4375, 18.875, 18.1875, 19.0, 18.4375, 18.5, 19.0625, 19.375, 19.5625, 20.25, 19.75, 20.5, 20.375, 20.0, 20.1875, 20.3125, 19.9375, 19.6875, 19.4375, 18.75, 19.625, 18.3125, 17.25, 16.25, 17.5, 18.0625, 12.75, 16.9375, 17.4375, 13.25, 12.5625, 12.4375, 12.0, 11.5, 11.875, 12.3125, 12.875, 12.6875, 12.9375, 11.625, 11.9375, 12.0625, 12.375, 12.1875, 11.8125, 11.6875, 12.25, 15.6875, 10.875, 10.75, 10.9375, 10.25, 10.5625, 10.5, ...

# %%
def event_probability(event_outcomes, sample_space):
    probability = (event_outcomes / sample_space) * 100
    return round(probability, 1)

# %%
# Sample Space
stock_data = len(Close)

# Determine the probability of drawing a particular number
lowest = 45.47999954223633
lowest_probability = event_probability(lowest,stock_data)

# Determine the probability of drawing a particular number
middle = 81.83999633789062
middle_probability = event_probability(middle, stock_data)

# Determine the probability of drawing a particular number
highest = 106.1500015258789
highest_probability = event_probability(highest, stock_data)

# Print each probability
print(str(lowest_probability) + '%')
print(str(middle_probability) + '%')
print(str(highest_probability) + '%')
# Out:
# 0.4%
# 0.8%
# 1.0%

# %%
# Sample Space
stock_data = len(Close)

# Outcomes
lowest = 45.47999954223633
highest = 106.1500015258789

# Probability of one red
lowest_probability = lowest / stock_data
highest_probability = highest / stock_data
lowest_highest = lowest_probability * highest_probability

# Lowest and Highest Probability Percent Code
lowest_highest_probability_percent = lowest_highest * 100
print(round(lowest_highest_probability_percent, 1))
# Out:
# 0.0

# %%
lowest_probability
# Out:
# 0.004229517301426237

# %%
highest_probability
# Out:
# 0.009871663863654692

# %% [markdown]
# ### Flip coins Probability

# %% [markdown]
# https://www.fourmilab.ch/rpkp/experiments/statistics.html

# %%
n = len(Close) 
get_sum = sum(Close) 
mean = get_sum / n 
print('Average:', mean)
# Out:
# Average: 16.035420784581753

# %%
Close.sort() 
if n % 2 == 0: 
    median1 = Close[n//2] 
    median2 = Close[n//2 - 1] 
    median = (median1 + median2)/2
else: 
    median = Close[n//2] 
print('Median:', median)
# Out:
# Median: 9.65625

# %%
from collections import Counter 

data = Counter(Close) 
get_mode = dict(data) 
for k,v in get_mode.items():
    if v==max(list(data.values())):
        mode = k
print('Mode:', mode)
# Out:
# Mode: 4.3125

# %%
minimum = min(Close)
maximum = max(Close)
range_numbers = maximum - minimum
print('Range Number:', range_numbers)
# Out:
# Range Number: 160.290003657341

# %%
variance= np.var(Close)
print('Variance:', variance)
# Out:
# Variance: 458.42484646226666

# %%
std = np.sqrt(variance)
print('Standard Deviation:', std)
# Out:
# Standard Deviation: 21.41085814399476

# %%
# Common Stock Number

num = np.array([53.79999923706055, 45.47999954223633, 52.38999938964844, 53.189998626708984, 56.38999938964844, 85.30999755859375, 86.70999908447266, 81.83999633789062, 82.41999816894531, 81.08999633789062, 82.54000091552734, 78.05999755859375, 81.55999755859375, 81.3499984741211, 81.43000030517578, 92.66000366210938, 79.05999755859375, 82.76000213623047, 78.55000305175781, 106.1500015258789])

# %%
heads_count = [np.random.binomial(n, 0.5) for n in num]
heads_count
# Out:
# [28,
#  17,
#  28,
#  32,
#  28,
#  47,
#  49,
#  40,
#  45,
#  39,
#  42,
#  41,
#  39,
#  41,
#  41,
#  47,
#  37,
#  38,
#  40,
#  51]

# %%
proportion_heads = heads_count/num
proportion_heads
# Out:
# array([0.5204461 , 0.37379068, 0.53445315, 0.60161686, 0.49654195,
#        0.55093191, 0.56510207, 0.48875858, 0.545984  , 0.48094712,
#        0.50884419, 0.52523701, 0.47817559, 0.50399509, 0.50349994,
#        0.50723072, 0.467999  , 0.459159  , 0.50922977, 0.48045218])

# %%
fig, ax = plt.subplots()
plt.xlabel('Number of coin flips in experiment')
plt.ylabel('Proportion of flips that are heads')
plt.axhline(0.5, color='orange')
_ = ax.scatter(num, proportion_heads)

# %%
n_experiments = 30 # times with stock data
stock_count = np.random.binomial(max(Close), 0.5, n_experiments)

# %%
stocks, event_count = np.unique(stock_count, return_counts=True)

# %%
stocks
# Out:
# array([66, 72, 73, 74, 75, 76, 77, 78, 79, 80, 84, 85, 87, 88, 89, 92, 93])

# %%
event_count
# Out:
# array([1, 1, 1, 3, 2, 2, 1, 2, 1, 3, 2, 2, 1, 3, 2, 2, 1], dtype=int64)

# %%
event_proba = event_count/n_experiments
event_proba
# Out:
# array([0.03333333, 0.03333333, 0.03333333, 0.1       , 0.06666667,
#        0.06666667, 0.03333333, 0.06666667, 0.03333333, 0.1       ,
#        0.06666667, 0.06666667, 0.03333333, 0.1       , 0.06666667,
#        0.06666667, 0.03333333])

# %%
plt.bar(stocks, event_proba, color='blue')
plt.xlabel('Stock(out of # tosses)')
plt.ylabel('Event probability')
plt.title('Number of probability')
# Out:
# Text(0.5, 1.0, 'Number of probability')

# %%
x = st.skewnorm.rvs(Close, size=len(Close))

# %%
fig, ax = plt.subplots()
plt.axvline(x = np.mean(x), color='orange')
_ = plt.hist(x, color = 'lightgray')

# %%
fig, ax = plt.subplots()
plt.axvline(x = np.mean(x), color='orange')
plt.axvline(x = np.median(x), color='green')
_ = plt.hist(x, color = 'lightgray')

# %% [markdown]
# ### Quantiles

# %%
np.median(x)
# Out:
# 0.6822201715366346

# %%
np.quantile(x, 0.5)
# Out:
# 0.6822201715366346

# %% [markdown]
# ### Percentiles

# %%
p = np.percentile(x, [95, 99])
p
# Out:
# array([1.96957911, 2.56668597])

# %%
fig, ax = plt.subplots()
plt.axvline(x = p[0], color='orange')
plt.axvline(x = p[1], color='red')
_ = plt.hist(x, color = 'lightgray')

# %%
np.quantile(x, [.95, .99])
# Out:
# array([1.96957911, 2.56668597])

# %%
q = np.percentile(x, [25, 50, 75])
q
# Out:
# array([0.31436129, 0.68222017, 1.15965487])

# %%
fig, ax = plt.subplots()
plt.axvline(x = q[0], color='cornflowerblue')
plt.axvline(x = q[1], color='green')
plt.axvline(x = q[2], color='cornflowerblue')
_ = plt.hist(x, color = 'lightgray')

# %%
### Deciles

# %%
d = np.percentile(x, range(10, 100, 10))
d
# Out:
# array([0.09710131, 0.2432367 , 0.38817724, 0.53893956, 0.68222017,
#        0.84821325, 1.04575055, 1.30530857, 1.68229801])

# %%
fig, ax = plt.subplots()
[plt.axvline(x = d_i, color='cornflowerblue') for d_i in d]
_ = plt.hist(x, color = 'lightgray')

# %% [markdown]
# ### Box-and-Whisker Plot

# %%
sns.boxplot(x=x)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Box edges and median are determined by quartiles

# %%
# Box edges define the inter-quartile range (IQR)
r = max(q) - min(q)
r
# Out:
# 0.8452935841991535

# %%
# 1.5 x IQR
min(q) - 1.5*r
# Out:
# -0.953579090492796

# %%
# whisker is plotted where that lowest value
np.min(x)
# Out:
# -1.0184367614876708

# %%
# upper whisker 
max(q) + 1.5*r
# Out:
# 2.427595246303818

# %%
# outliers and are plotted as individual points
x.sort()
x[-15:]
# Out:
# array([3.28917327, 3.29160431, 3.30506458, 3.30759385, 3.35057708,
#        3.39725105, 3.41373276, 3.41447524, 3.52414648, 3.54210131,
#        3.56448402, 3.57343625, 3.58015487, 3.58194499, 3.84106248])

# %% [markdown]
# ### Measures of Dispersion

# %%
xbar = np.mean(x)
xbar
# Out:
# 0.795744076934167

# %%
squared_differences = [(x_i - xbar)**2 for x_i in x]

# %%
squared_differences[0:10]
# Out:
# [3.2912521144969626,
#  3.187890182320878,
#  2.568225487852015,
#  2.542233403866638,
#  2.4327535517086645,
#  2.0950555837856517,
#  1.9752102815876351,
#  1.9186217408211934,
#  1.8428663788409008,
#  1.8202052082122067]

# %%
sigma_squared = sum(squared_differences)/len(x)
sigma_squared
# Out:
# 0.3902593412447493

# %%
np.var(x)
# Out:
# 0.39025934124474915

# %%
sigma = sigma_squared**(1/2)
sigma
# Out:
# 0.624707404506101

# %%
np.std(x)
# Out:
# 0.6247074045061008

# %%
fig, ax = plt.subplots()
plt.axvline(x = xbar, color='red')
plt.axvline(x = xbar+sigma, color='green')
plt.axvline(x = xbar-sigma, color='green')
_ = plt.hist(x, color = 'lightgray')

# %%
sigma/(len(x))**(1/2)
# Out:
# 0.006024372684092578

# %%
# defaults to 1 degree of freedom (n-1), which can be ignored with the larger data sets of Machine Learning
st.sem(x)
# Out:
# 0.006024652828838437

# %%
# 0 degrees of freedom (n)
st.sem(x, ddof=0)
# Out:
# 0.006024372684092577

# %% [markdown]
# ### The Central Limit Theorem

# %%
x_sample = np.random.choice(x, size=10, replace=False)
x_sample
# Out:
# array([0.70300474, 0.5472715 , 1.82207554, 0.14903374, 1.12993054,
#        1.14024255, 0.40027242, 1.67245412, 1.81843719, 0.93221609])

# %%
np.mean(x_sample)
# Out:
# 1.0314938429199327

# %%
# sampling distributions of 

def sample_mean_calculator(input_dist, sample_size, n_samples):
    sample_means = []
    for i in range(n_samples):
        sample = np.random.choice(input_dist, size=sample_size, replace=False)
        sample_means.append(sample.mean())
    return sample_means

# %%
sns.displot(sample_mean_calculator(x, 10, 10), color='green')
_ = plt.xlim(-1.5, 1.5)

# %%
sns.displot(sample_mean_calculator(x, 10, 1000), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)

# %%
sns.displot(sample_mean_calculator(x, 100, 100), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)

# %%
sns.displot(sample_mean_calculator(x, 100, 100), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)
